# %% [markdown]
# <h3>Alumno: Daniela Parra García</h3>
# <h3>Matricula: A01633687</h3>

# %% [markdown]
# # Notes Module 3

# %% [markdown]
# **Descriptive Statistics:**<br>
#
# Sumarize statistics of a dataframe:<br>
# df.**describe()**<br>
# Sumarize the categorical data of a column in a dataframe:<br>
# df.["columnName"].**value_counts()**<br>
#
# <br>
# <br>
#
# **Grouping data:**<br><br>
# Group data into categories(for categorical variables):<br>
# df_test = df[["columnName1", "columnName2", "columnName3"]]<br>
# df_grp = df_test.**groupby**(["columnName1", "columnName2"], as_index=False).mean()<br>
#
# See one variable in the columns and one in the rows (Pivot):<br>
# df_grp.**pivot**(index="columnName1", columns="columnName2")<br>
#
#
#
#
# <br>
# <br>

# %% [markdown]
# **Analysis of Variance (ANOVA):**<br><br>
# Find the correlation between different groups of a categorical variable<br>
# It returns two values: <br>
# F-test score: calculates the ratio of variation between the group's mean over the variation within each of the sample groups(score less than 1)<br>
# P-value: Shows wether the obtained result is statistically significant.(larger than 0.05)<br>
#
# How to apply ANOVA: <br>
# df_anova = df[["column1", "column2"]]<br>
# grouped_anova = df_anova.groupby(["column1"])<br>
# anova_result = stats.**f_oneway**( grouped_anova.get_group("string1InColumn1")["column2"], grouped_anova.get_group("string2InColumn1")["column2"] )<br>
#
# <br>
# <br>

# %% [markdown]
# **Correlation:**<br>
# Measures to what extent different variables are interdependent<br>
#
# Calculate the correlation between variables of type "int64" or "float64":<br>
# df.corr()<br>
# Calculate the correlation between some columns:<br>
# df[["column1", "column2", "column3"]].corr()<br>
#
# <br>
#
# **Pearson Correlation:**<br>
# Measure the strength of the correlation between two features<br><br>
# Gives two values:<br>
# Correlation coefficient:<br>
# Close to +1: Large Positive Relationship<br>
# Close to -1: Large Negative Relationship<br>
# Close to 0:  No Relationship<br>
# P-value:<br>
# P-value < 0.001: Strong certainty in the result<br>
# P-value < 0.05 : Moderate certainty in the result<br>
# P-value < 0.1  : Weak certainty in the result<br>
# P-value > 0.1  : No certainty in the result<br>
#
# Strong Correlation:<br>
# Correlation coeficient is close to 1 or -1 and<br>
# P-value is less than 0.001<br>
#
# <br>
# How to apply it:<br>
# pearson_coef, p_value = stats.**pearsonr**( df["column1"] , df["column2"] )<br>
#
#
# <br>
# <br>

# %% [markdown]
# **HeatMap**<br>
# Use HeatMap to plot target variables over multiple variables:<br>
# Helps when trying to see correlation in linear relationships<br>
# plt.pcolor(df_pivot, cmap='RdBu')<br>
# plt.colorbar()<br>
# plt.show()<br>
#
# <br>
#
# **Scatter Plot**<br>
# Helps when trying to see correlation in linear relationships<br>
# sns.regplot(x="column1", y="column2", data=df)<br>
# plt.ylim(0,)<br>
# <br>

# %% [markdown]
# **Box Plots**<br>
#
# Box Plots are a great way to visualize numeric data, like spot outliers, main features in a box plot:<br>
# Upper Extreme: 1.5 times the IQR above the 75th percentile<br>
# Upper Quartile: 75th percentile<br>
# Median: middle datapoint<br>
# data between upper and lower quartile: Interquartile range(IQR)<br>
# Lower Quartile: 25th percentile<br>
# Lower Extreme:  1.5 times the IQR below the 25th percentile <br>
#
# ![image.png](attachment:image.png)
#
#
# <br>
# <br>
