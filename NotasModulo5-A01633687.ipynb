# %% [markdown]
# <h3>Alumno: Daniela Parra García</h3>
# <h3>Matricula: A01633687</h3>

# %% [markdown]
# # Notes

# %% [markdown]
# <h3>Numpy 1D Arrays</h3> <br>
# <br>
# Check numpy version:<br>
# print(np.__version__)<br>
# <br>
# Import numpy:<br>
# import numpy as np<br>
# <br>
# Cast list to an numpy array:<br>
# a = [1,2]<br>
# x = np.array(a)<br>
# <br>
# Find the size of the array:<br>
# x.size<br>
# Find the number of dimensions of the array:<br>
# x.ndim<br>
# Find the shape of the array:<br>
# x.shape<br>
# Find the type of data of the array:<br>
# x.dtype<br>
# Find the mean of the array:<br>
# x.mean<br>
# Find the standard deviation of the array:<br>
# x.std()<br>
# <br>
# Slicing an array:<br>
# a[start:end:step]<br>
# <br>
# Vectors in NumPy:<br>
# u = np.array([1,0])<br>
# v = np.array([0,1])<br>
# Adding:<br>
# z=np.add(u,v)<br>
# z=u+v<br>
# Substraction:<br>
# z=np.subtract(u,v)<br>
# z=u-v<br>
# Division:<br>
# z=np.divide(u,v)<br>
# Multiplication:<br>
# z=np.multiply(u,v)<br>
# z = 2*u<br>
# Product:<br>
# z = u*v<br>
# Dot Product: (represents how similar two vectors are and returns a number)<br>
# z = np.dot(u,v)<br>
# Adding Constants: (broadcasting, adding constant to all the elements)<br>
# z = u+1<br>
# <br>
# Find the maximum value:<br>
# z = u.max()<br>
# Find the smallest value:<br>
# z = u.min()<br>
# <br>
# Get pi:<br>
# np.pi <br>
# <br>
# Get sin (for each element in the array):<br>
# np.sin(u)<br>
# <br>
# Linespace: (returns evenly spaced numbers over a specified interval)<br>
# np.linspace(startPoint, endPoint, num=samplesToGenerate) <br>
# np.linspace(-2,2,num=5) <br>

# %% [markdown]
# <h3>Numpy 2D Arrays </h3><br>
# <br>
# Cast list to an numpy array:<br>
# a = [[1,2],[3,4]]<br>
# x = np.array(a)<br>
# Find the number of axes/dimensions of the array (num of nested list):<br>
# x.ndim<br>
# Find the shape of the array ([numberOfNestedLists, sizeOfNestedList] or [numberOfRows, numberOfColumns]):<br>
# x.shape<br>
# Find the size of the array (number of rows x number of columns):<br>
# x.size<br>
# Find the type of data of the array:<br>
# x.dtype<br>
# <br>
# Slicing:<br>
# a[row, startColumn:endColumn]<br>
# a[0, 0: 1]<br>
# a[startRow:endRow, column]<br>
# a[0: 1, 1]<br>
# <br>
# Vectors in NumPy:<br>
# u = np.array([[1,2],[3,4]])<br>
# v = np.array([[0,1],[2,0]])<br>
# Adding:<br>
# z=np.add(u,v)<br>
# z=u+v<br>
# Multiplication:<br>
# z=np.multiply(u,v)<br>
# z = 2*u<br>
# Product:<br>
# z = u*v<br>
# Matrix multiplication:<br>
# A= np.array( [[0,1,10],[1,0,1]] )<br>
# B= np.array( [[1,1], [1,-1], [0,0]] )<br>
# C=np.dot(A,B)<br>
# Sin:<br>
# np.sin(C)<br>
# Transposed:<br>
# C.T<br>
# <br>

# %% [markdown]
# <h3>APIs</h3> <br>
# Import Request library:<br>
# import requests<br>
# <b>GET :</b><br>
# r = request.get(url)<br>
# r = request.get(url, params=payload)<br>
# <br>
# Get url:<br>
# r.url<br>
# Get response as text:<br>
# r.text<br>
# Get request status code:<br>
# r.status_code<br>
# Get the encoding:<br>
# r.encoding<br>
# Get request headers:<br>
# r.request.headers<br>
# Get request body:<br>
# r.request.body<br>
# Get response header:<br>
# header = r.headers<br>
# Get the date the request was sent:<br>
# header['date']<br>
# Get the type of data of the response:<br>
# header['Content-Type']<br>
# Read JSON(application/json): <br>
# r.json<br>
# use:<br>
# r.json()['args']
# Read text(text/html): <br>
# r.text[start:stop]<br>
# Read Image(image/png): <br>
# r.content<br>
# use:<br>
# path=os.path.join(os.getcwd(), imagePath)<br>
# with open(path, 'wb') as f<br>
# f.write(r.content)<br>
# <br>
# <b>POST :</b><br>
# r = request.post(url)<br>
# r = request.post(url, params=payload)<br>
# Get url:<br>
# r.url<br>
# Get request body:<br>
# r.request.body<br>
# Get the form of the json request:<br>
# r.json()['form']<br>

# %% [markdown]
# **Display Plt using Matplotlib:** <br>
# import matplotlib-pyplot as plt <br>
# plt.plot(x,y)<br>
# **Show Image in python:**<br>
# from PIL import Image<br>
# Image.open(path)<br>
